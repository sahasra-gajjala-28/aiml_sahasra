# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("data_clean.csv")
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
print(type(data))
print(data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (158, 10)

# %%
data.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
data1=data.drop(['Unnamed: 0','Temp C'],axis=1)
data1
# Out:
#      Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     5    1  2010    67       S
# 1     36.0    118.0   8.0     5    2  2010    72       C
# 2     12.0    149.0  12.6     5    3  2010    74      PS
# 3     18.0    313.0  11.5     5    4  2010    62       S
# 4      NaN      NaN  14.3     5    5  2010    56       S
# ..     ...      ...   ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     5    1  2010    67       C
# 154   30.0    193.0   6.9     9   26  2010    70      PS
# 155    NaN    145.0  13.2     9   27  2010    77       S
# 156   14.0    191.0  14.3     9   28  2010    75       S
# 157   18.0    131.0   8.0     9   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Month    158 non-null    object
#  4   Day      158 non-null    int64
#  5   Year     158 non-null    int64
#  6   Temp     158 non-null    int64
#  7   Weather  155 non-null    object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 10.0+ KB

# %%
#convert  the month to float to datatype
data1['Month']=pd.to_numeric(data['Month'],errors='coerce')
data1
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    5.0    4  2010    62       S
# 4      NaN      NaN  14.3    5.0    5  2010    56       S
# ..     ...      ...   ...    ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    9.0   27  2010    77       S
# 156   14.0    191.0  14.3    9.0   28  2010    75       S
# 157   18.0    131.0   8.0    9.0   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Month    157 non-null    float64
#  4   Day      158 non-null    int64
#  5   Year     158 non-null    int64
#  6   Temp     158 non-null    int64
#  7   Weather  155 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 10.0+ KB

# %%
#checking for duplicate rows one only 
data1[data1.duplicated()]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 156   14.0    191.0  14.3    9.0   28  2010    75       S

# %%
data1[data1.duplicated(keep=False)]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 150   14.0    191.0  14.3    9.0   28  2010    75       S
# 156   14.0    191.0  14.3    9.0   28  2010    75       S

# %%
data1.rename({'Solar.R':'Solar','Temp':'Temperature'},axis=1,inplace=True)
data1
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temperature Weather
# 0     41.0  190.0   7.4    5.0    1  2010           67       S
# 1     36.0  118.0   8.0    5.0    2  2010           72       C
# 2     12.0  149.0  12.6    5.0    3  2010           74      PS
# 3     18.0  313.0  11.5    5.0    4  2010           62       S
# 4      NaN    NaN  14.3    5.0    5  2010           56       S
# ..     ...    ...   ...    ...  ...   ...          ...     ...
# 153   41.0  190.0   7.4    5.0    1  2010           67       C
# 154   30.0  193.0   6.9    9.0   26  2010           70      PS
# 155    NaN  145.0  13.2    9.0   27  2010           77       S
# 156   14.0  191.0  14.3    9.0   28  2010           75       S
# 157   18.0  131.0   8.0    9.0   29  2010           76       C
#
# [158 rows x 8 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Ozone        120 non-null    float64
#  1   Solar        151 non-null    float64
#  2   Wind         158 non-null    float64
#  3   Month        157 non-null    float64
#  4   Day          158 non-null    int64
#  5   Year         158 non-null    int64
#  6   Temperature  158 non-null    int64
#  7   Weather      155 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 10.0+ KB

# %%
data1.isnull().sum()
# Out:
# Ozone          38
# Solar           7
# Wind            0
# Month           1
# Day             0
# Year            0
# Temperature     0
# Weather         3
# dtype: int64

# %%
#visualize
cols=data1.columns
colours=['black','yellow']
sns.heatmap(data1[cols].isnull(),cmap=sns.color_palette(colours),cbar=True)
# Out:
# <Axes: >

# %%
#median and mean
median=data1['Ozone'].median()
mean=data1['Ozone'].mean()
print("MEDIAN",median)
print("mean",mean)
# Out:
# MEDIAN 30.5
# mean 41.583333333333336

# %%
#replace the qzone missing values with median value
data1['Ozone']=data1['Ozone'].fillna(median)
data1.isnull().sum()
# Out:
# Ozone          0
# Solar          7
# Wind           0
# Month          1
# Day            0
# Year           0
# Temperature    0
# Weather        3
# dtype: int64

# %%
data1['Solar']=data1['Solar'].fillna(median)
data1.isnull().sum()
# Out:
# Ozone          0
# Solar          0
# Wind           0
# Month          1
# Day            0
# Year           0
# Temperature    0
# Weather        3
# dtype: int64

# %%
print(data1["Weather"].value_counts())
mode_weather = data1["Weather"].mode()[0]
print(mode_weather)
# Out:
# Weather
# S     59
# C     49
# PS    47
# Name: count, dtype: int64
# S

# %%
data1["Weather"] = data1["Weather"].fillna(mode_weather)
data1.isnull().sum()
# Out:
# Ozone          0
# Solar          0
# Wind           0
# Month          0
# Day            0
# Year           0
# Temperature    0
# Weather        0
# dtype: int64

# %%
print(data1["Month"].value_counts())
mode_Month = data1["Month"].mode()[0]
print(mode_Month)
# Out:
# Month
# 9.0    34
# 5.0    31
# 7.0    31
# 8.0    31
# 6.0    30
# Name: count, dtype: int64
# 9.0

# %%
data1["Month"] = data1["Month"].fillna(mode_Month)
data1.isnull().sum()
# Out:
# Ozone          0
# Solar          0
# Wind           0
# Month          0
# Day            0
# Year           0
# Temperature    0
# Weather        0
# dtype: int64

# %%
data1.tail()
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temperature Weather
# 153   41.0  190.0   7.4    5.0    1  2010           67       C
# 154   30.0  193.0   6.9    9.0   26  2010           70      PS
# 155   30.5  145.0  13.2    9.0   27  2010           77       S
# 156   14.0  191.0  14.3    9.0   28  2010           75       S
# 157   18.0  131.0   8.0    9.0   29  2010           76       C

# %%
data1.reset_index(drop=True)
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temperature Weather
# 0     41.0  190.0   7.4    5.0    1  2010           67       S
# 1     36.0  118.0   8.0    5.0    2  2010           72       C
# 2     12.0  149.0  12.6    5.0    3  2010           74      PS
# 3     18.0  313.0  11.5    5.0    4  2010           62       S
# 4     30.5   30.5  14.3    5.0    5  2010           56       S
# ..     ...    ...   ...    ...  ...   ...          ...     ...
# 153   41.0  190.0   7.4    5.0    1  2010           67       C
# 154   30.0  193.0   6.9    9.0   26  2010           70      PS
# 155   30.5  145.0  13.2    9.0   27  2010           77       S
# 156   14.0  191.0  14.3    9.0   28  2010           75       S
# 157   18.0  131.0   8.0    9.0   29  2010           76       C
#
# [158 rows x 8 columns]

# %%
fig, axes = plt.subplots(2, 1, figsize=(8,6), gridspec_kw={'height_ratios':[1,3]})
sns.boxplot(data=data1["Ozone"], ax =axes[0], color='skyblue', width=0.5, orient ='h')
axes[0].set_title("Boxplot")
axes[0].set_xlabel("Ozone Levels")
sns.histplot(data=data1["Ozone"], kde=True, ax =axes[1], color='purple', bins=30)
axes[1].set_title("Histogram with KDE")
axes[1].set_xlabel("Ozone Levels")
axes[1].set_ylabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### observations
#  - the ozone column has extreme values beyond 81 as seen from box plot
#  - the same is confirmed fro the below right-skewed histogram

# %%
fig, axes = plt.subplots(2, 1, figsize=(8,6), gridspec_kw={'height_ratios':[1,3]})
sns.boxplot(data=data1["Solar"], ax =axes[0], color='skyblue', width=0.5, orient ='h')
axes[0].set_title("Boxplot")
axes[0].set_xlabel("Solar Levels")
sns.histplot(data=data1["Solar"], kde=True, ax =axes[1], color='purple', bins=30)
axes[1].set_title("Histogram with KDE")
axes[1].set_xlabel("Solar Levels")
axes[1].set_ylabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### observations
# - in the solor column there are no outliers
# - the graph is sligtly left-skewed histogram

# %%
sns.violinplot (data=data1["Solar"],color = 'ligthgreen')
plt.title("violinplot")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 sns.violinplot (data=data1["Solar"],color = 'ligthgreen')
#       2 plt.title("violinplot")
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\seaborn\categorical.py:1755, in violinplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, inner, split, width, dodge, gap, linewidth, linecolor, cut, gridsize, bw_method, bw_adjust, density_norm, common_norm, hue_norm, formatter, log_scale, native_scale, legend, scale, scale_hue, bw, inner_kws, ax, **kwargs)
#    1753 saturation = saturation if fill else 1
#    1754 p.map_hue(palette=palette, order=hue_order, norm=hue_norm, saturation=saturation)
# -> 1755 color = _default_color(
#    1756     ax.fill_between, hue, color,
#    1757     {k: v for k, v in kwargs.items() if k in ["c", "color", "fc", "facecolor"]},
#    1758     saturation=saturation,
#    1759 )
#    1760 linecolor = p._complement_color(linecolor, color, p._hue_map)
#    1762 density_norm, common_norm = p._violin_scale_backcompat(
#    1763     scale, scale_hue, density_norm, common_norm,
#    1764 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\seaborn\utils.py:85, in _default_color(method, hue, color, kws, saturation)
#      83 if color is not None:
#      84     if saturation < 1:
# ---> 85         color = desaturate(color, saturation)
#      86     return color
#      88 elif method.__name__ == "plot":
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\seaborn\utils.py:168, in desaturate(color, prop)
#     165     raise ValueError("prop must be between 0 and 1")
#     167 # Get rgb tuple rep
# --> 168 rgb = to_rgb(color)
#     170 # Short circuit to avoid floating point issues
#     171 if prop == 1:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\matplotlib\colors.py:526, in to_rgb(c)
#     524 def to_rgb(c):
#     525     """Convert *c* to an RGB color, silently dropping the alpha channel."""
# --> 526     return to_rgba(c)[:3]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\matplotlib\colors.py:314, in to_rgba(c, alpha)
#     312     rgba = None
#     313 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 314     rgba = _to_rgba_no_colorcycle(c, alpha)
#     315     try:
#     316         _colors_full_map.cache[c, alpha] = rgba
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\matplotlib\colors.py:391, in _to_rgba_no_colorcycle(c, alpha)
#     387             raise ValueError(
#     388                 f"Invalid string grayscale value {orig_c!r}. "
#     389                 f"Value must be within 0-1 range")
#     390         return c, c, c, alpha if alpha is not None else 1.
# --> 391     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     392 # turn 2-D array into 1-D array
#     393 if isinstance(c, np.ndarray):
#
# ValueError: Invalid RGBA argument: 'ligthgreen'
